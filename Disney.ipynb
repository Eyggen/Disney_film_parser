# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import time

# %%
r = requests.get("https://en.wikipedia.org/wiki/Toy_Story_3")

soup = bs(r.content)

contents = soup.prettify()

# %%
def get_listed_data(data):
    patt = data.get_text(" ", strip=True)
    if data.find("li"):
        return [li.get_text(" ", strip=True).replace("\xa0", " ") for li in data.find_all('li')]
    elif data.find('br'):
        return [text for text in data.stripped_strings]
    else:
        return data.get_text(" ", strip=True).replace("\xa0", " ")

def clean_tags(soup):
    for tag in soup.find_all('sup'):
        tag.decompose()
    

    
def get_movie_info_to_dict(href):
    req = "https://en.wikipedia.org" + href
    r = requests.get(req)
    soup = bs(r.content)
    
    clean_tags(soup)
    
    info_box = soup.find(class_ = "infobox vevent")
    info_rows = info_box.find_all("tr")

    movie_info = {}    
    for index, value in enumerate(info_rows):
        if index == 0:
            movie_info['title'] = value.find('th').get_text(" ", strip=True)
        else:
            header = value.find('th')
            if header:  
                key = value.find(class_ = "infobox-label").get_text(" ", strip=True)
                content = get_listed_data(value.find(class_ = "infobox-data"))
                movie_info[key] = content
    return movie_info

# %%
get_movie_info_to_dict('/wiki/Howl%27s_Moving_Castle_(film)')
# Out:
# {'title': "Howl's Moving Castle",
#  'Japanese': 'ハウルの動く城',
#  'Hepburn': 'Hauru no Ugoku Shiro',
#  'Directed by': 'Hayao Miyazaki',
#  'Screenplay by': 'Hayao Miyazaki',
#  'Based on': ["Howl's Moving Castle", 'by', 'Diana Wynne Jones'],
#  'Produced by': 'Toshio Suzuki',
#  'Starring': ['Chieko Baisho', 'Takuya Kimura', 'Akihiro Miwa'],
#  'Cinematography': 'Atsushi Okui',
#  'Edited by': 'Takeshi Seyama',
#  'Music by': 'Joe Hisaishi',
#  'Production company': 'Studio Ghibli',
#  'Distributed by': 'Toho',
#  'Release dates': ['5 September 2004 ( 2004-09-05 ) ( Venice )',
#   '20 November 2004 ( 2004-11-20 ) (Japan)'],
#  'Running time': '119 minutes',
#  'Country': 'Japan',
#  'Language': 'Japanese',
#  'Budget': ['¥', '2.4 billion', 'US$24 million'],
#  'Box office': ['¥', '23.2 billion', 'US$236 million (worldwide)']}

# %%
def href_preprop(href):
    regex = '^/.+'
    pattern = re.compile(regex)
    return pattern.search(href) is not None


r = requests.get("https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films")
soup = bs(r.content)

tables_of_movies = soup.find_all(class_="wikitable sortable")

tables_of_movies.pop(len(tables_of_movies)-1)

hrefs = []


for tables in tables_of_movies:
    for i in tables.find_all("i"):
        for a in i.find_all("a", href=True):
            if href_preprop(a['href']):
                hrefs.append(a['href'])

# %%
movies = []
for index, href in enumerate(hrefs):
    if index % 10 == 0:
        print(index)
    try:
        movies.append(get_movie_info_to_dict(href))
    except Exception as ex:
        print(href)
        print(ex)
        continue
# Out:
# 0
# 10
# 20
# 30
# 40
# /wiki/Zorro_(1957_TV_series)#Theatrical
# 'NoneType' object has no attribute 'get_text'
# /wiki/Zorro_(1957_TV_series)#Theatrical
# 'NoneType' object has no attribute 'get_text'
# 50
# 60
# 70
# 80
# 90
# 100
# 110
# 120
# 130
# 140
# 150
# 160
# 170
# 180
# 190
# 200
# 210
# 220
# 230
# 240
# 250
# 260
# 270
# 280
# 290
# 300
# 310
# 320
# 330
# 340
# 350
# 360
# 370
# 380
# 390
# 400
# 410
# 420
# 430
# 440
# 450
# 460
# 470
# 480
# 490
# /wiki/The_Beatles:_Get_Back#The_Beatles:_Get_Back_–_The_Rooftop_Concert
# 'NoneType' object has no attribute 'get_text'
# 500
# /wiki/Wish_(2023_film)
# 'NoneType' object has no attribute 'find_all'
# /wiki/Elio_(film)
# 'NoneType' object has no attribute 'find_all'
# 510

# %%
import json

def save_data(title, data):
    with open(title, "w", encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %%
import json

def load_data(title):
    with open(title, encoding='utf-8') as f:
        return json.load(f)

# %%
movies = load_data("disney_movies_data_float.json")

# %%
def minutes_to_int(run_time):
    if run_time == "N/A":
        return None
    if isinstance(run_time, list):
        return int(run_time[0].split(" ")[0])
    else:
         return int(run_time.split(" ")[0])

#for movie in movies:
#    movie["Running time (int)"] = minutes_to_int(movie.get("Running time", 'N/A'))

# %%
import re

def get_float_nums(a):
    for index, budget in enumerate(a):
        if budget == "N/A":
            a[index] = budget #print(budget, index)
        if isinstance(budget, list):
            for elem in budget:
                pattern_1 = re.findall(r"~?\$[0-9]+[.0-9]*[–|-|—|-][0-9]+ million", elem)
                pattern_2 = re.findall(r"~?\$[0-9]+\,0+", elem)
                pattern_3 = re.findall(r"~?\$[0-9]+\.*[0-9]* million", elem) 
                if len(pattern_1)>0:
                    res = budget[0].split("-")[0].replace('$', '').replace('~', '')
                    res = res.split("-")[0]
                    res = res.split("—")[0]
                    a[index] = res.split("–")[0] + ' million'
                elif len(pattern_2)>0:
                    a[index] = pattern_2[0].replace(',000',' k').replace('$', '').replace('~', '')#print(pattern_1[0], index)
                elif len(pattern_3)>0:
                    a[index] = pattern_3[0].replace(' million',' m').replace('$', '').replace('~', '') #print(pattern_2[0], index)
                else:
                    a[index] = "N/A"

        else: 
            pattern_1 = re.findall(r"~?\$[0-9]+[.0-9]*[–|-|—|-][0-9]+ million", budget)
            pattern_2 = re.findall(r"~?\$[0-9]+\,0+", budget)
            pattern_3 = re.findall(r"~?\$[0-9]+\.*[0-9]* million", budget) 
            pattern_4 = re.findall(r"~?\$[0-9]+\,[0-9,]+", budget)
            if len(pattern_1)>0:
                res = budget.split("—")[0].replace('$', '').replace('~', '')
                res = res.split("-")[0]
                res = res.split("-")[0]
                a[index] = res.split("–")[0] + ' m'
            elif len(pattern_2)>0:
                a[index] = pattern_2[0].replace(',000',' k').replace('$', '').replace('~', '')#print(pattern_1[0], index)
            elif len(pattern_3)>0:
                a[index] = pattern_3[0].replace(' million',' m').replace('$', '').replace('~', '') #print(pattern_2[0], index)
            elif len(pattern_4)>0:
                a[index] = pattern_4[0].replace('00,000',' m').replace('$', '').replace('~', '').replace(',', '.')
            else:
                a[index] = "N/A"

    for index, budget in enumerate(a):
        if budget == "N/A":
            a[index] = None
        elif "m" in budget:
            a[index] = float(budget.replace(' m', '')) * 1000000
        elif "k" in budget:
            a[index] = float(budget.replace(' k', '')) * 1000
        else:
            a[index] = float(budget.replace(',', '').replace('.', ''))
            
    return a
# Out:
# [418000000.0, 164000000.0, 83300000.0, 960000.0, 1300000.0, 267399999.99999997, 1135000.0, 799000.0, 3355000.0, 3275000.0, 65000000.0, 3165000.0, 2560000.0, 575000.0, 1625000.0, 182000000.0, 4099999.9999999995, 3500000.0, 2100000.0, 87400000.0, 1000000.0, 2600000.0, None, 1750000.0, 28200000.0, 2150000.0, 187000000.0, 2100000.0, 1600000.0, 1700000.0, None, None, 2750000.0, None, 1750000.0, 6250000.0, None, 1800000.0, 2500000.0, 51600000.0, 12300000.0, 2300000.0, 1700000.0, 3100000.0, None, 3750000.0, 2300000.0, None, 40000000.0, 303000000.0, 11426000.0, 25100000.0, None, None, 4600000.0, 3500000.0, 5000000.0, None, None, None, 21745500.0, 22100000.0, 2550000.0, 3000.0, 4350000.0, 4200000.0, 22200000.0, 1600000.0, 4000.0, 2250000.0, 3500000.0, 103100000.0, 3500000.0, 1275000.0, 4000.0, 280.0, 6200000.0, 22565634.0, None, 16207116.0, 3000.0, 1900000.0, 4000.0, 378000000.0, None, 5000000.0, 21540050.0, 2250000.0, 4150000.0, 3300000.0, 51300000.0, 1300000.0, None, 5500000.0, None, 18607492.0, 4000000.0, 191000000.0, None, None, 5100000.0, 17900000.0, None, 4610000.0, None, None, 6100000.0, 22583370.0, None, 2000000.0, 33000000.0, 7000000.0, 30800000.0, 4000000.0, None, 10000000.0, 6600000.0, 20000.0, 36853000.0, 5500000.0, None, None, None, None, None, 21873000.0, 10500000.0, 36000000.0, None, None, None, 169000000.0, 29000000.0, None, None, None, None, None, None, 20931111.0, 4475000.0, None, 2900000.0, 5000000.0, 18000000.0, 11000000.0, 60000000.0, 16000000.0, None, 14100000.0, 63500000.0, None, 8000000.0, 50000000.0, 7400000.0, 4304286.0, 8400000.0, 27600000.0, 11100000.0, 21300000.0, 9700000.0, 13000000.0, 38700000.0, 18564613.0, 22300000.0, 13687027.0, 121000000.0, 222700000.0, 8153677.0, 235000000.0, 18100000.0, 47400000.0, 41000000.0, 15100000.0, 7300000.0, 46700000.0, 440100000.0, 2800000.0, 96000000.0, 50800000.0, 504100000.0, 27200000.0, 57000000.0, 12900000.0, 24100000.0, 45400000.0, 154900000.0, 111000000.0, 21000000.0, 39000000.0, 45600000.0, 8878839.0, None, 968500000.0, 50200000.0, 3337685.0, 190300000.0, 70700000.0, 17600000.0, 400.0, 8199999.999999999, 37600000.0, 346100000.0, 24670346.0, 13400000.0, 17700000.0, None, 363000000.0, 23900000.0, 34300000.0, 32700000.000000004, 37700000.0, 325300000.0, None, 26465920.0, 22900000.0, 320700000.0, 18300000.0, 59900000.0, None, 252700000.0, 174400000.0, 27800000.0, 15400000.0, 178000000.0, 28900000.0, 4400000.0, 304300000.0, 92100000.0, None, 12200000.0, 363300000.0, 50600000.0, 36800000.0, 19400000.0, None, 448200000.0, 134400000.0, 6400000.0, None, 511300000.0, 96200000.0, None, 500000.0, 349800000.0, 90900000.0, 110300000.0, None, None, 136800000.0, 183600000.0, 169600000.0, 44500000.0, None, 186100000.0, 165300000.0, 18600000.0, 577400000.0, None, 115000000.0, 115100000.0, None, None, 80700000.0, 273100000.0, 18000000.0, 395800000.0, 19300000.0, 172900000.0, 110000000.0, None, 135700000.0, None, 62900000.0, 28700000.0, 71400000.0, 55500000.0, 940300000.0, 654300000.0, 160800000.0, None, None, 250400000.0, 182300000.0, 9638389.0, 6500000.0, 64500000.0, None, 33299999.999999996, None, 76500000.0, 1108356.0, 72200000.0, 314402.0, 134700000.0, None, 631600000.0, None, 347500000.0, 9000000.0, None, 52900000.0, 198600000.0, 27600000.0, None, 144100000.0, 236000000.0, 86400000.0, 61700000.0, None, None, 15400000.0, 314400000.0, 745000000.0, None, 42900000.0, 11000000.0, None, 120500000.0, 87100000.0, 102300000.0, 462000000.0, None, None, 58500000.0, None, 91500000.0, 110800000.0, None, None, 137600000.0, 169300000.0, 960900000.0, 623700000.0, None, 65300000.0, None, 146600000.0, 340500000.0, 459200000.0, 70600000.0, 51500000.0, 419600000.0, 521299999.99999994, None, 149300000.0, 275776.0, 252900000.0, 2000000.0, 9200000.0, 310000000.0, 212900000.0, 23100000.0, 106400000.0, 155500000.0, 109000000.0, 55513.0, 735100000.0, None, 292800000.0, None, None, 8582265.0, 11300000.0, 325300000.0, 96800000.0, 271000000.0, None, 82700000.0, 336400000.0, None, 215300000.0, 75500000.0, Non ...

# %%
arr_of_float_budget = get_float_nums([movie.get("Budget", "N/A") for movie in movies])
arr_of_float_box_office = get_float_nums([movie.get("Box office", "N/A") for movie in movies])

for index, movie in enumerate(movies):
    movie["Budget (float)"] = arr_of_float_budget[index]

for index, movie in enumerate(movies):
    movie["Box office (float)"] = arr_of_float_box_office[index]

# %%
from datetime import datetime 

arr_of_str_data = [movie.get("Release dates", "N/A") for movie in movies]

def clean_data(date):
    return date.split("(")[0].strip()

def date_convertation(date):
    if isinstance(date, list):
        date = date[0]
    
    if date == "N/A":
        return None
    
    date_str = clean_data(date)
    fmts = ["%B %d, %Y", "%d %B %Y"]
    for fmt in fmts:
        try:
            return datetime.strptime(date_str, fmt)
        except:
            pass
    return None

for date in arr_of_str_data:
    print(date_convertation(date))
    print()
# Out:
# 1937-12-21 00:00:00
#
# 1940-02-07 00:00:00
#
# None
#
# None
#
# 1941-10-23 00:00:00
#
# 1942-08-09 00:00:00
#
# 1942-08-24 00:00:00
#
# None
#
# 1944-12-21 00:00:00
#
# 1946-04-20 00:00:00
#
# 1946-11-12 00:00:00
#
# None
#
# None
#
# 1948-11-29 00:00:00
#
# None
#
# 1950-02-15 00:00:00
#
# 1950-06-22 00:00:00
#
# 1951-07-26 00:00:00
#
# 1952-03-13 00:00:00
#
# None
#
# None
#
# None
#
# 1953-10-26 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1959-06-24 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1962-11-14 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1963-12-12 00:00:00
#
# None
#
# None
#
# 1963-12-11 00:00:00
#
# None
#
# 1964-08-27 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# 1966-02-04 00:00:00
#
# 1966-06-25 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1967-06-23 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# 1968-12-24 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1970-12-11 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1976-12-17 00:00:00
#
# 1976-05-26 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1979-07-19 00:00:00
#
# 1979-12-18 00:00:00
#
# None
#
# 1980-04-17 00:00:00
#
# None
#
# None
#
# 1980-12-06 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1983-10-07 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1988-03-24 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1990-10-03 00:00:00
#
# None
#
# None
#
# 1991-09-29 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1994-11-05 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1995-01-22 00:00:00
#
# 1995-11-19 00:00:00
#
# None
#
# None
#
# None
#
# 1996-04-12 00:00:00
#
# 1996-06-19 00:00:00
#
# None
#
# None
#
# None
#
# 1996-11-18 00:00:00
#
# None
#
# 1997-03-07 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 1997-11-16 00:00:00
#
# None
#
# None
#
# 1998-06-05 00:00:00
#
# None
#
# None
#
# None
#
# 1998-11-14 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# 1999-06-12 00:00:00
#
# None
#
# 1999-05-21 00:00:00
#
# None
#
# 1999-11-13 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# 1999-12-17 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 2000-12-10 00:00:00
#
# 2001-02-10 00:00:00
#
# None
#
# 2001-06-03 00:00:00
#
# 2001-07-29 00:00:00
#
# None
#
# 2001-10-28 00:00:00
#
# None
#
# None
#
# 2002-02-10 00:00:00
#
# None
#
# None
#
# None
#
# 2002-06-16 00:00:00
#
# 2002-07-21 00:00:00
#
# None
#
# None
#
# 2002-10-23 00:00:00
#
# 2002-11-06 00:00:00
#
# None
#
# None
#
# None
#
# 2003-03-16 00:00:00
#
# 2003-03-31 00:00:00
#
# None
#
# None
#
# 2003-05-18 00:00:00
#
# 2003-06-28 00:00:00
#
# 2003-08-04 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 2004-10-24 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 2005-05-10 00:00:00
#
# 2004-09-05 00:00:00
#
# None
#
# 2005-03-25 00:00:00
#
# None
#
# None
#
# None
#
# 2005-10-30 00:00:00
#
# 2005-12-07 00:00:00
#
# None
#
# None
#
# None
#
# 2006-01-26 00:00:00
#
# None
#
# None
#
# None
#
# 2006-05-26 00:00:00
#
# 2006-06-23 00:00:00
#
# 2006-06-16 00:00:00
#
# None
#
# None
#
# 1993-10-13 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# 2007-03-23 00:00:00
#
# 2007-05-19 00:00:00
#
# 2007-06-22 00:00:00
#
# 2007-06-29 00:00:00
#
# None
#
# None
#
# 2007-09-23 00:00:00
#
# 2007-10-20 00:00:00
#
# None
#
# None
#
# None
#
# 2008-05-07 00:00:00
#
# 2008-06-23 00:00:00
#
# None
#
# 2008-09-18 00:00:00
#
# None
#
# 2008-10-17 00:00:00
#
# 2008-10-23 00:00:00
#
# None
#
# 2008-11-17 00:00:00
#
# None
#
# None
#
# 2009-03-11 00:00:00
#
# None
#
# 2007-10-10 00:00:00
#
# 2009-04-24 00:00:00
#
# 2009-05-13 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# 2009-06-05 00:00:00
#
# None
#
# 2009-11-03 00:00:00
#
# None
#
# 2009-11-25 00:00:00
#
# 2010-02-25 00:00:00
#
# 2009-10-17 00:00:00
#
# 2010-05-09 00:00:00
#
# 2010-06-12 00:00:00
#
# 2010-07-08 00:00:00
#
# None
#
# 2008-10-26 00:00:00
#
# 2010-08-13 00:00:00
#
# 2010-09-30 00:00:00
#
# None
#
# 2010-11-14 00:00:00
#
# 2010-11-30 00:00:00
#
# None
#
# None
#
# None
#
# 2011-03-06 00:00:00
#
# None
#
# 2011-04-22 00:00:00
#
# None
#
# 2011-05-07 00:00:00
#
# 2011-06-18 00:00:00
#
# 2011-04-06 00:00:00
#
# None
#
# 2011-11-04 00:00:00
#
# None
#
# None
#
# 2012-02-22 00:00:00
#
# 2012-04-20 00:00:00
#
# None
#
# 2012-06-10 00:00:00
#
# None
#
# None
#
# 2012-09-20 00:00:00
#
# 2012-08-16 00:00:00
#
# 2012-10-29 00:00:00
#
# 2013-02-14 00:00:00
#
# 2011-03-16 00:00:00
#
# 2013-06-05 00:00:00
#
# 2013-06-22 00:00:00
#
# 2013-08-02 00:00:00
#
# None
#
# 2013-11-19 00:00:00
#
# 2013-10-20 00:00:00
#
# 2014-03-11 00:00:00
#
# 2014-02-13 00:00:00
#
# None
#
# 2014-05-06 00:00:00
#
# 2014-05-28 00:00:00
#
# 2014-07-15 00:00:00
#
# None
#
# 2014-10-06 00:00:00
#
# 2014-10-23 00:00:00
#
# 2014-12-08 00:00:00
#
# 2015-02-09 00:00:00
#
# 2014-12-12 00:00:00
#
# 2015-02-13 00:00:00
#
# None
#
# 2015-05-09 00:00:00
#
# 2015-05-18 00:00:00
#
# None
#
# 2015-11-10 00:00:00
#
# 2016-01-25 00:00:00
#
# 2016-02-13 00:00:00
#
# 2016-04-04 00:00:00
#
# 2016-04-23 00:00:00
#
# 2016-05-10 00:00:00
#
# 2016-06-08 00:00:00
#
# 2016-05-14 00:00:00
#
# 2016-08-08 00:00:00
#
# 2016-09-10 00:00:00
#
# 2016-11-14 00:00:00
#
# 2016-12-21 00:00:00
#
# None
#
# 2017-02-23 00:00:00
#
# 2016-08-12 00:00:00
#
# 2017-05-11 00:00:00
#
# 2017-05-23 00:00:00
#
# None
#
# None
#
# None
#
# 2017-10-20 00:00:00
#
# 2018-02-26 00:00:00
#
# 2018-06-05 00:00:00
#
# 2018-07-30 00:00:00
#
# 2018-10-29 00:00:00
#
# 2018-11-05 00:00:00
#
# 2018-11-29 00:00:00
#
# 2019-03-11 00:00:00
#
# None
#
# 2019-05-08 00:00:00
#
# 2019-06-11 00:00:00
#
# 2019-07-09 00:00:00
#
# None
#
# None
#
# None
#
# 2019-11-07 00:00:00
#
# None
#
# 2020-01-25 00:00:00
#
# 2020-02-21 00:00:00
#
# None
#
# 2018-03-28 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 2020-03-09 00:00:00
#
# None
#
# None
#
# 2020-10-11 00:00:00
#
# 2020-12-24 00:00:00
#
# None
#
# None
#
# 2021-05-18 00:00:00
#
# 2021-06-13 00:00:00
#
# 2021-07-24 00:00:00
#
# 2021-11-03 00:00:00
#
# None
#
# None
#
# None
#
# 2022-03-01 00:00:00
#
# 2022-03-16 00:00:00
#
# 2022-03-15 00:00:00
#
# None
#
# 2022-05-16 00:00:00
#
# 2022-05-23 00:00:00
#
# 2022-06-08 00:00:00
#
# None
#
# None
#
# None
#
# 2022-11-16 00:00:00
#
# 2022-11-15 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 2015-05-18 00:00:00
#
# 2019-07-09 00:00:00

# %%
for movie in movies:
    movie["Release dates (datetime)"] = date_convertation(movie.get("Release dates", "N/A"))

movies[1]
# Out:
# {'title': 'Pinocchio',
#  'Directed by': ['Ben Sharpsteen',
#   'Hamilton Luske',
#   'Bill Roberts',
#   'Norman Ferguson',
#   'Jack Kinney',
#   'Wilfred Jackson',
#   'T. Hee'],
#  'Story by': ['Ted Sears',
#   'Otto Englander',
#   'Webb Smith',
#   'William Cottrell',
#   'Joseph Sabo',
#   'Erdman Penner',
#   'Aurelius Battaglia'],
#  'Based on': ['The Adventures of Pinocchio', 'by', 'Carlo Collodi'],
#  'Produced by': 'Walt Disney',
#  'Starring': ['Cliff Edwards',
#   'Dickie Jones',
#   'Christian Rub',
#   'Walter Catlett',
#   'Charles Judels',
#   'Evelyn Venable',
#   'Frankie Darro'],
#  'Music by': ['Leigh Harline', 'Paul J. Smith'],
#  'Production company': 'Walt Disney Productions',
#  'Distributed by': 'RKO Radio Pictures',
#  'Release dates': ['February 7, 1940 ( 1940-02-07 ) ( Center Theatre )',
#   'February 23, 1940 ( 1940-02-23 ) (United States)'],
#  'Running time': '88 minutes',
#  'Country': 'United States',
#  'Language': 'English',
#  'Budget': '$2.6 million',
#  'Box office': '$164 million',
#  'Running time (int)': 88,
#  'Budget (float)': 2600000.0,
#  'Box office (float)': 164000000.0,
#  'Release dates (datetime)': datetime.datetime(1940, 2, 7, 0, 0)}

# %%
import pickle

def save_date_pickle(name, data):
    with open(name, "wb") as f:
        pickle.dump(data, f)

# %%
import pickle

def load_date_pickle(name):
    with open(name, "rb") as f:
        return pickle.load(f)

# %%
save_date_pickle("disney_movies_data_clean.pickle", movies)

# %%
a = load_date_pickle("disney_movies_data_clean.pickle")

# %%
import os
import urllib
import requests

def get_omdb_info(title):
    base_url = "https://www.omdbapi.com/?"
    parameters = {
        "apikey":"e29e5c69", #os.environ['OMDb_API_Key'],
        "t":title
    }
    params_encoded = urllib.parse.urlencode(parameters)
    full_url = base_url + params_encoded
    return requests.get(full_url).json()

def get_rotten_tomato_score(omdb_info):
    ratings = omdb_info.get("Ratings", [])
    for rating in ratings:
        if rating['Source'] == "Rotten Tomatoes":
            return rating["Value"]
    return None

# %%
for movie in movies:
    title = movie["title"]
    omdb_info = get_omdb_info(title)
    movie['imdb'] = omdb_info.get("imdbRating", None)
    movie['Metascore'] = omdb_info.get("Metascore", None)
    movie['Rotten Tomatoes'] = get_rotten_tomato_score(omdb_info)

# %%
save_date_pickle("disney_movies_data_clean_final.pickle", movies)

# %%
import pandas as pd

df = pd.DataFrame(movies)
df.to_csv("disney_movies_data_clean_final.csv")

# %%
df.head(-5)
# Out:
#                                           title  \
# 0               Snow White and the Seven Dwarfs
# 1                                     Pinocchio
# 2                                      Fantasia
# 3                          The Reluctant Dragon
# 4                                         Dumbo
# ..                                          ...
# 498                                Disenchanted
# 499                               Strange World
# 500         Diary of a Wimpy Kid: Rodrick Rules
# 501  Night at the Museum: Kahmunrah Rises Again
# 502                          The Little Mermaid
#
#                                            Directed by  \
# 0    [David Hand, William Cottrell, Wilfred Jackson...
# 1    [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...
# 2    [Samuel Armstrong, James Algar, Bill Roberts, ...
# 3    [Alfred Werker, (live action), Hamilton Luske,...
# 4    [Ben Sharpsteen, Norman Ferguson, Wilfred Jack...
# ..                                                 ...
# 498                                      Adam Shankman
# 499                                           Don Hall
# 500                                      Luke Cormican
# 501                                        Matt Danner
# 502                                       Rob Marshall
#
#                                             Written by  \
# 0    [Ted Sears, Richard Creedon, Otto Englander, D...
# 1                                                  NaN
# 2                                                  NaN
# 3    [Live-action:, Ted Sears, Al Perkins, Larry Cl...
# 4                                                  NaN
# ..                                                 ...
# 498                                                NaN
# 499                                                NaN
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
#
#                                               Based on  \
# 0                 [Snow White, by The, Brothers Grimm]
# 1     [The Adventures of Pinocchio, by, Carlo Collodi]
# 2                                                  NaN
# 3                                                  NaN
# 4    [Dumbo, the Flying Elephant, by, Helen Aberson...
# ..                                                 ...
# 498                       [Characters, by, Bill Kelly]
# 499                                                NaN
# 500  [Diary of a Wimpy Kid: Rodrick Rules, by Jeff ...
# 501  [Characters, by, Thomas Lennon, Robert Ben Gar...
# 502  [Disney 's The Little Mermaid by Ron Clements ...
#
#                                            Produced by  \
# 0                                          Walt Disney
# 1                                          Walt Disney
# 2                        [Walt Disney, Ben Sharpsteen]
# 3                                          Walt Disney
# 4                                          Walt Disney
# ..                                                 ...
# 498     [Barry Josephson, Barry Sonnenfeld, Amy Adams]
# 499                                          Roy Conli
# 500                                        Jeff Kinney
# 501                                         Shawn Levy
# 502  [Marc Platt, Lin-Manuel Miranda, Rob Marshall,...
#
#                                               Starring  \
# 0    [Adriana Caselotti, Lucille La Verne, Harry St...
# 1    [Cliff Edwards, Dickie Jones, Christian Rub, W...
# 2                    [Leopold Stokowski, Deems Taylor]
# 3    [Robert Benchley, Frances Gifford, Buddy Peppe...
# 4    [Edward Brophy, Verna Felton, Cliff Edwards, H...
# ..                                                 ...
# 498  [Amy Adams, Patrick Dempsey, Maya Rudolph, Yve...
# 499  [Jake Gyllenhaal, Dennis Quaid, Jaboukie Young...
# 500  [Brady Noon, Hunter Dillon, Ethan William Chil...
# 501  [Joshua Bassett, Jamie Demetriou, Alice Isaaz,...
# 502  [Halle Bailey, Daveed Diggs, Jacob Tremblay, A...
#
#                                          Music by       Production company  \
# 0    [Frank Churchill, Paul Smith, Leigh Harline]  Walt Disney Productions
# 1                  [Leigh Harline, Paul J. Smith]  Walt Disney Productions
# 2                                     See program  Walt Disney Productions
# 3                  [Frank Churchill, Larry Morey]  Walt Disney Productions
# 4               [Frank Churchill, Oliver Wallace]  Walt Disney Productions
# ..                                            ...                      ...
# 498                                   Alan Menken                      NaN
# 499                                 Henry Jackman                      NaN
# 500                                  John Paesano                      NaN
# 501                                  John Paesano                      NaN
# 502                                   Alan Menken                      NaN
#
#                                       Distributed by  \
# 0                                 RKO Radio Pictures
# 1                                 RKO Radio Pictures
# 2                                 RKO Radio Pictures
# 3                                 RKO Radio Pictures
# 4                                 RKO Radio Pictures
# ..                                               ...
# 498                                          Disney+
# 499           [Walt Disney Studios, Motion Pictures]
# 500                                          Disney+
# 501  [Disney+ (Worldwide), Alibaba Pictures (China)]
# 502              Walt Disney Studios Motion Pictures
#
#                                          Release dates  ...  \
# 0    [December 21, 1937 ( 1937-12-21 ) ( Carthay Ci...  ...
# 1    [February 7, 1940 ( 1940-02-07 ) ( Center Thea...  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4    [October 23, 1941 ( 1941-10-23 ) (New York Cit...  ...
# ..                                                 ...  ...
# 498  [November 16, 2022 ( 2022-11-16 ) ( El Capitan...  ...
# 499  [November 15, 2022 ( 2022-11-15 ) ( El Capitan...  ...
# 500                                                NaN  ...
# 501                                                NaN  ...
# 502                                                NaN  ...
#
#                           Countries Color process  \
# 0                               NaN           NaN
# 1                               NaN           NaN
# 2                               NaN           NaN
# 3                               NaN           NaN
# 4                               NaN           NaN
# ..                              ...           ...
# 498                             NaN           NaN
# 499                             NaN           NaN
# 500         [United States, Canada]           NaN
# 501  [United States, Canada, China]           NaN
# 502                             NaN           NaN
#
#                                   Production companies Japanese Hepburn  \
# 0                                                  NaN      NaN     NaN
# 1                                                  NaN      NaN     NaN
# 2                                                  NaN      NaN     NaN
# 3                                                  NaN      NaN     NaN
# 4                                                  NaN      NaN     NaN
# ..                                                 ...      ...     ...
# 498  [Walt Disney Pictures, Josephson Entertainment...      NaN     NaN
# 499  [Walt Disney Pictures, Walt Disney Animation S...      NaN     NaN
# 500       [Walt Disney Pictures, Bardel Entertainment]      NaN     NaN
# 501  [Walt Disney Pictures, 21 Laps Entertainment, ...      NaN     NaN
# 502  [Walt Disney Pictures, Lucamar Productions, Ma...      NaN     NaN
#
#      Adaptation by  Traditional  Simplified Original title Layouts by
# 0              NaN          NaN         NaN            NaN        NaN
# 1              NaN          NaN         NaN            NaN        NaN
# 2              NaN          NaN         NaN            NaN        NaN
# 3              NaN          NaN         NaN            NaN        NaN
# 4              NaN          NaN         NaN            NaN        NaN
# ..             ...          ...         ...            ...        ...
# 498            NaN          NaN         NaN            NaN        NaN
# 499            NaN          NaN         NaN            NaN        NaN
# 500            NaN          NaN         NaN            NaN        NaN
# 501            NaN          NaN         NaN            NaN        NaN
# 502            NaN          NaN         NaN            NaN        NaN
#
# [503 rows x 39 columns]
